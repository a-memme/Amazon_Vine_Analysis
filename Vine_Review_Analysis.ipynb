# %%
import pandas as pd

# %%
vine_df = pd.read_csv("vine_table.csv")
vine_df
# Out:
#               review_id  star_rating  helpful_votes  total_votes vine  \
# 0        R3DT59XH7HXR9K          5.0            0.0          0.0    N
# 1        R1LFS11BNASSU8          5.0            0.0          1.0    N
# 2        R296RT05AG0AF6          5.0            0.0          0.0    N
# 3        R3V37XDZ7ZCI3L          5.0            0.0          1.0    N
# 4        R14GU232NQFYX2          5.0            0.0          0.0    N
# ...                 ...          ...            ...          ...  ...
# 4880461  R22DLC2P26MUMR          4.0           30.0         41.0    N
# 4880462  R1N6KLTENLQOMT          5.0           84.0         92.0    N
# 4880463  R10TW4QXDV8KJC          4.0           55.0         60.0    N
# 4880464   R41RL2U1FSQ4V          4.0           30.0         42.0    N
# 4880465  R1NHMPKSJG2E37          5.0            5.0          5.0    N
#
#         verified_purchase
# 0                       Y
# 1                       Y
# 2                       Y
# ...

# %%
# New dataframe where total_votes >= 20
votes_df = vine_df[vine_df["total_votes"]>= 20]
votes_df.head(30)
# Out:
#            review_id  star_rating  helpful_votes  total_votes vine  \
# 18    R28RB82UG4RDD5          5.0           20.0         20.0    N
# 233   R3FB6BERWPEIJP          4.0           40.0         43.0    N
# 615   R1D4Z38STRDQXK          5.0           53.0         56.0    N
# 1065  R1XMWJZICINIFX          3.0           20.0         21.0    N
# 1105  R20QKY1GABXFLM          1.0          272.0        297.0    N
# 1434  R3GZ7CK2O1PPG0          2.0           10.0         30.0    N
# 1504  R328FA1E6FY3F5          5.0           17.0         20.0    N
# 1538  R3DH22AA5WGLLS          5.0           30.0         30.0    N
# 1713  R1E0E5EFZSLJCS          1.0           66.0         80.0    N
# 1999  R1TXZQWEHYWEWN          2.0           48.0         51.0    N
# 2003   RQQAI8YL3UCY2          5.0           23.0         25.0    N
# 2159  R3PZNAQREFUNJ7          4.0           28.0         35.0    N
# 2407  R1ZUNUSUEA5D0T          2.0           17.0         20.0    N
# ...

# %%
votes_df.dtypes
# Out:
# review_id             object
# star_rating          float64
# helpful_votes        float64
# total_votes          float64
# vine                  object
# verified_purchase     object
# dtype: object

# %%
# New dataframe where number of helpful_votes / total_votes is greater or equal to 50%
new_votes_df = votes_df[votes_df["helpful_votes"] / votes_df["total_votes"] >= 0.5]
new_votes_df.head(30)
# Out:
#            review_id  star_rating  helpful_votes  total_votes vine  \
# 18    R28RB82UG4RDD5          5.0           20.0         20.0    N
# 233   R3FB6BERWPEIJP          4.0           40.0         43.0    N
# 615   R1D4Z38STRDQXK          5.0           53.0         56.0    N
# 1065  R1XMWJZICINIFX          3.0           20.0         21.0    N
# 1105  R20QKY1GABXFLM          1.0          272.0        297.0    N
# 1504  R328FA1E6FY3F5          5.0           17.0         20.0    N
# 1538  R3DH22AA5WGLLS          5.0           30.0         30.0    N
# 1713  R1E0E5EFZSLJCS          1.0           66.0         80.0    N
# 1999  R1TXZQWEHYWEWN          2.0           48.0         51.0    N
# 2003   RQQAI8YL3UCY2          5.0           23.0         25.0    N
# 2159  R3PZNAQREFUNJ7          4.0           28.0         35.0    N
# 2407  R1ZUNUSUEA5D0T          2.0           17.0         20.0    N
# 2508  R3SHJSHTY8AXKR          5.0           69.0         72.0    N
# ...

# %%
paid_review = new_votes_df[new_votes_df["vine"]== "Y"]
paid_review
# Out:
#               review_id  star_rating  helpful_votes  total_votes vine  \
# 13470    R1Z71RW4J9IK93          5.0           20.0         22.0    Y
# 18140    R3FVB5QI11KI9Q          4.0          192.0        200.0    Y
# 20156    R2G027YBMVXV6Y          5.0           39.0         48.0    Y
# 26393    R1QGBAN7BMGWRR          5.0          121.0        129.0    Y
# 28369    R2NH2AU7XL9ZDZ          3.0           18.0         20.0    Y
# ...                 ...          ...            ...          ...  ...
# 4662711  R2D7ZSUZ5LME8B          3.0           37.0         48.0    Y
# 4662751   RPNMEK7LNID1S          4.0          129.0        136.0    Y
# 4662752  R1K9IAOAHMQFFK          5.0           80.0         85.0    Y
# 4663306  R3JJWL3N25MFSE          5.0          317.0        329.0    Y
# 4663754  R1T3LTPPABEWPK          5.0           59.0         63.0    Y
#
#         verified_purchase
# 13470                   N
# 18140                   N
# 20156                   N
# ...

# %%
unpaid_review = new_votes_df[new_votes_df["vine"]== "N"]
unpaid_review
# Out:
#               review_id  star_rating  helpful_votes  total_votes vine  \
# 18       R28RB82UG4RDD5          5.0           20.0         20.0    N
# 233      R3FB6BERWPEIJP          4.0           40.0         43.0    N
# 615      R1D4Z38STRDQXK          5.0           53.0         56.0    N
# 1065     R1XMWJZICINIFX          3.0           20.0         21.0    N
# 1105     R20QKY1GABXFLM          1.0          272.0        297.0    N
# ...                 ...          ...            ...          ...  ...
# 4880460  R2SLX958DGMAIG          4.0           21.0         21.0    N
# 4880461  R22DLC2P26MUMR          4.0           30.0         41.0    N
# 4880462  R1N6KLTENLQOMT          5.0           84.0         92.0    N
# 4880463  R10TW4QXDV8KJC          4.0           55.0         60.0    N
# 4880464   R41RL2U1FSQ4V          4.0           30.0         42.0    N
#
#         verified_purchase
# 18                      Y
# 233                     Y
# 615                     Y
# ...

# %%
# Count total number of ratings for paid reviews
total_reviews = paid_review["review_id"].count()
total_reviews
# Out:
# 1207

# %%
#Count number of ratings with 5 stars for paid reviews
five_stars_df = paid_review[paid_review["star_rating"] == 5.0]
five_stars = five_stars_df["star_rating"].count()
five_stars
# Out:
# 509

# %%
# Calculate percentage of 5-star reviews for paid reviews 
fivestart_percent = five_stars / total_reviews * 100
fivestart_percent
# Out:
# 42.17067108533554

# %%
# Create a function to find the total number of reviews, total number of 5 star reviews, 
# and percentage of 5 star reviews for each review type
def reviews(review_type):
    
    total = review_type["review_id"].count()
    
    five_stars_df = review_type[review_type["star_rating"] == 5.0]
    five_stars = five_stars_df["star_rating"].count()
    
    fivestar_percent = five_stars / total * 100
    
    return print (f"The total number of reviews is {total}.\nThe total number of 5 star reviews is {five_stars}.\nThe percentage of 5 star reviews is {fivestar_percent:.2f}%.")

# %%
reviews(paid_review)
# Out:
# The total number of reviews is 1207.
# The total number of 5 star reviews is 509.
# The percentage of 5 star reviews is 42.17%.

# %%
reviews(unpaid_review)
# Out:
# The total number of reviews is 97839.
# The total number of 5 star reviews is 45858.
# The percentage of 5 star reviews is 46.87%.
